# %% [markdown]
# # api_dev_correlation_function_development
# * Author: Jea Kwon
# * Description: developing rolling window correlation function in avatar

# %%
import datetime
import avatarpy
today = datetime.datetime.today().strftime('%Y-%m-%d')
print('Date: ', today, '\nVersion: ', avatarpy.__version__)
# Out:
# Date:  2021-05-06
# Version:  0.0.4

# %%
from avatarpy import Avatar, dataset
import os
import glob
import itertools
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import cufflinks as cf
import plotly.express as px
from scipy import stats
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
cf.go_offline(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
csv_path = dataset['freely_moving']

# %%
ava = Avatar(csv_path)

# %% [markdown]
# # Example) limb-wise velocity correlation

# %%
corr = ava.velocity.corr()
corr
# Out:
#            nose      neck      anus     chest     rfoot     lfoot     rhand  \
# nose   1.000000  0.846679  0.337655  0.666609  0.202680  0.208653  0.490393
# neck   0.846679  1.000000  0.469334  0.807822  0.279971  0.286010  0.565957
# anus   0.337655  0.469334  1.000000  0.744020  0.627957  0.611615  0.426210
# chest  0.666609  0.807822  0.744020  1.000000  0.500490  0.501775  0.586647
# rfoot  0.202680  0.279971  0.627957  0.500490  1.000000  0.246747  0.260187
# lfoot  0.208653  0.286010  0.611615  0.501775  0.246747  1.000000  0.301125
# rhand  0.490393  0.565957  0.426210  0.586647  0.260187  0.301125  1.000000
# lhand  0.503752  0.562241  0.410555  0.564098  0.282862  0.264743  0.352924
# tip    0.230852  0.323338  0.560513  0.421291  0.385252  0.356357  0.258368
#
#           lhand       tip
# nose   0.503752  0.230852
# neck   0.562241  0.323338
# anus   0.410555  0.560513
# chest  0.564098  0.421291
# rfoot  0.282862  0.385252
# lfoot  0.264743  0.356357
# rhand  0.352924  0.258368
# lhand  1.000000  0.288193
# tip    0.288193  1.000000

# %% [markdown]
# * Output: exact square,
# to remove duplicate, apply triangular mask

# %%
mask = np.tril(np.ones(corr.shape).astype(np.bool))
corr.mask(mask)
# Out:
#        nose      neck      anus     chest     rfoot     lfoot     rhand  \
# nose    NaN  0.846679  0.337655  0.666609  0.202680  0.208653  0.490393
# neck    NaN       NaN  0.469334  0.807822  0.279971  0.286010  0.565957
# anus    NaN       NaN       NaN  0.744020  0.627957  0.611615  0.426210
# chest   NaN       NaN       NaN       NaN  0.500490  0.501775  0.586647
# rfoot   NaN       NaN       NaN       NaN       NaN  0.246747  0.260187
# lfoot   NaN       NaN       NaN       NaN       NaN       NaN  0.301125
# rhand   NaN       NaN       NaN       NaN       NaN       NaN       NaN
# lhand   NaN       NaN       NaN       NaN       NaN       NaN       NaN
# tip     NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
#           lhand       tip
# nose   0.503752  0.230852
# neck   0.562241  0.323338
# anus   0.410555  0.560513
# chest  0.564098  0.421291
# rfoot  0.282862  0.385252
# lfoot  0.264743  0.356357
# rhand  0.352924  0.258368
# lhand       NaN  0.288193
# tip         NaN       NaN

# %%
# total unique inter-node correlations
corr.mask(mask).count().sum()
# Out:
# 36

# %%
# flatten 2d-arr
corr_flatten = corr.mask(mask).stack().reset_index()
corr_flatten
# Out:
#    level_0 level_1         0
# 0     nose    neck  0.846679
# 1     nose    anus  0.337655
# 2     nose   chest  0.666609
# 3     nose   rfoot  0.202680
# 4     nose   lfoot  0.208653
# 5     nose   rhand  0.490393
# 6     nose   lhand  0.503752
# 7     nose     tip  0.230852
# 8     neck    anus  0.469334
# 9     neck   chest  0.807822
# 10    neck   rfoot  0.279971
# 11    neck   lfoot  0.286010
# 12    neck   rhand  0.565957
# 13    neck   lhand  0.562241
# 14    neck     tip  0.323338
# 15    anus   chest  0.744020
# 16    anus   rfoot  0.627957
# 17    anus   lfoot  0.611615
# 18    anus   rhand  0.426210
# 19    anus   lhand  0.410555
# 20    anus     tip  0.560513
# 21   chest   rfoot  0.500490
# 22   chest   lfoot  0.501775
# 23   chest   rhand  0.586647
# 24   chest   lhand  0.564098
# 25   chest     tip  0.421291
# 26   rfoot   lfoot  0.246747
# 27   rfoot   rhand  0.260187
# 28   rfoot   lhand  0.282862
# 29   rfoot     tip  0.385252
# 30   lfoot   rhand  0.301125
# 31   lfoot   lhand  0.264743
# 32   lfoot     tip  0.356357
# 33   rhand   lhand  0.352924
# 34   rhand     tip  0.258368
# 35   lhand     tip  0.288193

# %%
labels = pd.Index(['-'.join(x) for x in zip( corr_flatten['level_0'], corr_flatten['level_1'])])
corrs = corr_flatten.set_index(labels)[0]

# %%
corrs
# Out:
# nose-neck      0.846679
# nose-anus      0.337655
# nose-chest     0.666609
# nose-rfoot     0.202680
# nose-lfoot     0.208653
# nose-rhand     0.490393
# nose-lhand     0.503752
# nose-tip       0.230852
# neck-anus      0.469334
# neck-chest     0.807822
# neck-rfoot     0.279971
# neck-lfoot     0.286010
# neck-rhand     0.565957
# neck-lhand     0.562241
# neck-tip       0.323338
# anus-chest     0.744020
# anus-rfoot     0.627957
# anus-lfoot     0.611615
# anus-rhand     0.426210
# anus-lhand     0.410555
# anus-tip       0.560513
# chest-rfoot    0.500490
# chest-lfoot    0.501775
# chest-rhand    0.586647
# chest-lhand    0.564098
# chest-tip      0.421291
# rfoot-lfoot    0.246747
# rfoot-rhand    0.260187
# rfoot-lhand    0.282862
# rfoot-tip      0.385252
# lfoot-rhand    0.301125
# lfoot-lhand    0.264743
# lfoot-tip      0.356357
# rhand-lhand    0.352924
# rhand-tip      0.258368
# lhand-tip      0.288193
# Name: 0, dtype: float64

# %% [markdown]
# ## Applying Rolling Window for Correlation

# %% [markdown]
# Note that there is kwarg applied to rolling window, `center=True`.
# The calculated correlation values will be appear at center of window.

# %%
window = 20
rolling_corr = ava.velocity[['rfoot', 'lfoot', 'lhand', 'rhand']].rolling(window, center=True).corr()
rolling_corr.dropna()
# Out:
#                 rfoot     lfoot     lhand     rhand
# 0.55  rfoot  1.000000  0.737912  0.384960 -0.323462
#       lfoot  0.737912  1.000000  0.420771  0.259220
#       lhand  0.384960  0.420771  1.000000 -0.230745
#       rhand -0.323462  0.259220 -0.230745  1.000000
# 0.60  rfoot  1.000000  0.673841  0.269956 -0.304451
# ...               ...       ...       ...       ...
# 99.45 rhand -0.081409  0.600330  0.043031  1.000000
# 99.50 rfoot  1.000000  0.312290  0.174261 -0.086313
#       lfoot  0.312290  1.000000  0.056661  0.639690
#       lhand  0.174261  0.056661  1.000000  0.058932
#       rhand -0.086313  0.639690  0.058932  1.000000
#
# [7920 rows x 4 columns]

# %% [markdown]
# ## Function for flattening correlation matrix

# %%
def corr_flatten(df):
    mask = np.tril(np.ones(df.shape).astype(np.bool))
    s = df.mask(mask).stack()
    s.index = s.index.map(lambda x: '_'.join(x[-2:]))
    return s

# %%
corr_flatten(corr)
# Out:
# nose_neck      0.846679
# nose_anus      0.337655
# nose_chest     0.666609
# nose_rfoot     0.202680
# nose_lfoot     0.208653
# nose_rhand     0.490393
# nose_lhand     0.503752
# nose_tip       0.230852
# neck_anus      0.469334
# neck_chest     0.807822
# neck_rfoot     0.279971
# neck_lfoot     0.286010
# neck_rhand     0.565957
# neck_lhand     0.562241
# neck_tip       0.323338
# anus_chest     0.744020
# anus_rfoot     0.627957
# anus_lfoot     0.611615
# anus_rhand     0.426210
# anus_lhand     0.410555
# anus_tip       0.560513
# chest_rfoot    0.500490
# chest_lfoot    0.501775
# chest_rhand    0.586647
# chest_lhand    0.564098
# chest_tip      0.421291
# rfoot_lfoot    0.246747
# rfoot_rhand    0.260187
# rfoot_lhand    0.282862
# rfoot_tip      0.385252
# lfoot_rhand    0.301125
# lfoot_lhand    0.264743
# lfoot_tip      0.356357
# rhand_lhand    0.352924
# rhand_tip      0.258368
# lhand_tip      0.288193
# dtype: float64

# %% [markdown]
# ### Apply row by row

# %%
rolling_corr.groupby(level=0).apply(lambda x: corr_flatten(x)).unstack()
# Out:
#        lfoot_lhand  lfoot_rhand  lhand_rhand  rfoot_lfoot  rfoot_lhand  \
# 0.55      0.420771     0.259220    -0.230745     0.737912     0.384960
# 0.60      0.408157     0.254535    -0.244439     0.673841     0.269956
# 0.65      0.396234     0.245848    -0.260584     0.543175     0.250063
# 0.70      0.397881     0.235739    -0.260875     0.534893     0.253469
# 0.75      0.412008     0.234537    -0.246392     0.530713     0.264173
# ...            ...          ...          ...          ...          ...
# 99.30    -0.162736     0.560084    -0.140074     0.115347     0.158081
# 99.35    -0.099045     0.561452    -0.062731     0.122395     0.234593
# 99.40    -0.016024     0.562232     0.038515     0.175089     0.196344
# 99.45     0.029806     0.600330     0.043031     0.274165     0.162219
# 99.50     0.056661     0.639690     0.058932     0.312290     0.174261
#
#        rfoot_rhand
# 0.55     -0.323462
# 0.60     -0.304451
# 0.65     -0.262604
# 0.70     -0.278345
# 0.75     -0.286510
# ...            ...
# 99.30    -0.103764
# 99.35    -0.093553
# 99.40    -0.033585
# 99.45    -0.081409
# 99.50    -0.086313
#
# [1980 rows x 6 columns]

# %%
def get_rolling_corr(data, window=20, center=True):
    rolling_corr = data.rolling(window, center=center).corr()
    return rolling_corr.groupby(level=0).apply(lambda x: corr_flatten(x)).unstack()

# %% [markdown]
# # Usage

# %%
get_rolling_corr(ava.velocity[['rfoot', 'lfoot', 'lhand', 'rhand']]).iplot(kind='heatmap', colorscale='-rdbu')
# Out:
# <div>                            <div id="5c115ac9-28bb-43a7-8df6-7ba614050eb8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("5c115ac9-28bb-43a7-8df6-7ba614050eb8")) {                    Plotly.newPlot(                        "5c115ac9-28bb-43a7-8df6-7ba614050eb8",                        [{"colorscale": [[0.0, "rgb(5,48,97)"], [0.1, "rgb(33,102,172)"], [0.2, "rgb(67,147,195)"], [0.3, "rgb(146,197,222)"], [0.4, "rgb(209,229,240)"], [0.5, "rgb(247,247,247)"], [0.6, "rgb(253,219,199)"], [0.7, "rgb(244,165,130)"], [0.8, "rgb(214,96,77)"], [0.9, "rgb(178,24,43)"], [1.0, "rgb(103,0,31)"]], "type": "heatmap", "x": [0.55, 0.6, 0.65, 0.7, 0.75, 0.8, 0.85, 0.9, 0.95, 1.0, 1.05, 1.1, 1.15, 1.2, 1.25, 1.3, 1.35, 1.4, 1.45, 1.5, 1.55, 1.6, 1.65, 1.7, 1.75, 1.8, 1.85, 1.9, 1.95, 2.0, 2.05, 2.1, 2.15, 2.2, 2.25, 2.3, 2.35, 2.4, 2.45, 2.5, 2.55, 2.6, 2.65, 2.7, 2.75, 2.8, 2.85, 2.9, 2.95, 3.0, 3.05, 3.1, 3.15, 3.2, 3.25, 3.3, 3.35, 3.4, 3.45, 3.5, 3.55, 3.6, 3.65, 3.7, 3.75, 3.8, 3.85, 3.9, 3.95, 4.0, 4.05, 4.1, 4.15, 4.2, 4.25, 4.3, 4.35, 4.4, 4.45, 4.5, 4.55, 4.6, 4.65, 4.7, 4.75, 4.8, 4.85, 4.9, 4.95, 5.0, 5.05, 5.1, 5.15, 5.2, 5.25, 5.3, 5.35, 5.4, 5.45, 5.5, 5.55, 5.6, 5.65, 5.7, 5.75, 5.8, 5.85, 5.9, 5.95, 6.0, 6.05, 6.1, 6.15, 6.2, 6.25, 6.3, 6.35, 6.4, 6.45, 6.5, 6.55, 6.6, 6.65, 6.7, 6.75, 6.8, 6.85, 6.9, 6.95, 7.0, 7.05, 7.1, 7.15, 7.2, 7.25, 7.3, 7.35, 7.4, 7.45, 7.5, 7.55, 7.6, 7.65, 7.7, 7.75, 7.8, 7.85, 7.9, 7.95, 8.0, 8.05, 8.1, 8.15, 8.2, 8.25, 8.3, 8.35, 8.4, 8.45, 8.5, 8.55, 8.6, 8.65, 8.7, 8.75, 8.8, 8.85, 8.9, 8.95, 9.0, 9.05, 9.1, 9.15, 9.2, 9.25, 9.3, 9.35, 9.4, 9.45, 9.5, 9.55, 9.6, 9.65, 9.7, 9.75, 9.8, 9.85, 9.9, 9.95, 10.0, 10.05, 10.1, 10.15, 10.2, 10.25, 10.3, 10.35, 10.4, 10.45, 10.5, 10.55, 10.6, 10.65, 10.7, 10.75, 10.8, 10.85, 10.9, 10.95, 11.0, 11.05, 11.1, 11.15, 11.2, 11.25, 11.3, 11.35, 11.4, 11.45, 11.5, 11.55, 11.6, 11.65, 11.7, 11.75, 11.8, 11.85, 11.9, 11.95, 12.0, 12.05, 12.1, 12.15, 12.2, 12.25, 12.3, 12.35, 12.4, 12.45, 12.5, 12.55, 12.6, 12.65, 12.7, 12.75, 12